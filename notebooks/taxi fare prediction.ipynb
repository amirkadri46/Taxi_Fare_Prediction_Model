# %%
import pandas as pd
import numpy as np

# %%
taxi = pd.read_csv(r"C:\Users\Aamir\Downloads\TaxiFare.csv",index_col=0,header=0)

# %%
taxi
# Out:
#            amount      date_time_of_pickup  longitude_of_pickup  \
# unique_id
# 26:21.0       4.5  2009-06-15 17:26:21 UTC           -73.844311
# 52:16.0      16.9  2010-01-05 16:52:16 UTC           -74.016048
# 35:00.0       5.7  2011-08-18 00:35:00 UTC           -73.982738
# 30:42.0       7.7  2012-04-21 04:30:42 UTC           -73.987130
# 51:00.0       5.3  2010-03-09 07:51:00 UTC           -73.968095
# ...           ...                      ...                  ...
# 25:15.0      15.0  2013-06-12 23:25:15 UTC           -73.999973
# 19:18.0       7.5  2015-06-22 17:19:18 UTC           -73.984756
# 53:00.0       6.9  2011-01-30 04:53:00 UTC           -74.002698
# 09:00.0       4.5  2012-11-06 07:09:00 UTC           -73.946062
# 13:14.0      10.9  2010-01-13 08:13:14 UTC           -73.932603
#
#            latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# unique_id
# 26:21.0             40.721319            -73.841610            40.712278
# ...

# %%
taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 26:21.0 to 13:14.0
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   amount                50000 non-null  float64
#  1   date_time_of_pickup   50000 non-null  datetime64[ns, UTC]
#  2   longitude_of_pickup   50000 non-null  float64
#  3   latitude_of_pickup    50000 non-null  float64
#  4   longitude_of_dropoff  50000 non-null  float64
#  5   latitude_of_dropoff   50000 non-null  float64
#  6   no_of_passenger       50000 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(1)
# memory usage: 3.1+ MB

# %%
taxi.date_time_of_pickup=pd.to_datetime(taxi.date_time_of_pickup)

# %%
taxi
# Out:
#            amount       date_time_of_pickup  longitude_of_pickup  \
# unique_id
# 26:21.0       4.5 2009-06-15 17:26:21+00:00           -73.844311
# 52:16.0      16.9 2010-01-05 16:52:16+00:00           -74.016048
# 35:00.0       5.7 2011-08-18 00:35:00+00:00           -73.982738
# 30:42.0       7.7 2012-04-21 04:30:42+00:00           -73.987130
# 51:00.0       5.3 2010-03-09 07:51:00+00:00           -73.968095
# ...           ...                       ...                  ...
# 25:15.0      15.0 2013-06-12 23:25:15+00:00           -73.999973
# 19:18.0       7.5 2015-06-22 17:19:18+00:00           -73.984756
# 53:00.0       6.9 2011-01-30 04:53:00+00:00           -74.002698
# 09:00.0       4.5 2012-11-06 07:09:00+00:00           -73.946062
# 13:14.0      10.9 2010-01-13 08:13:14+00:00           -73.932603
#
#            latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# unique_id
# 26:21.0             40.721319            -73.841610            40.712278
# ...

# %%
taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 26:21.0 to 13:14.0
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   amount                50000 non-null  float64
#  1   date_time_of_pickup   50000 non-null  datetime64[ns, UTC]
#  2   longitude_of_pickup   50000 non-null  float64
#  3   latitude_of_pickup    50000 non-null  float64
#  4   longitude_of_dropoff  50000 non-null  float64
#  5   latitude_of_dropoff   50000 non-null  float64
#  6   no_of_passenger       50000 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(1)
# memory usage: 3.1+ MB

# %%
taxi.describe()
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  50000.000000         50000.000000        50000.000000
# mean      11.364171           -72.509756           39.933759
# std        9.685557            10.393860            6.224857
# min       -5.000000           -75.423848          -74.006893
# 25%        6.000000           -73.992062           40.734880
# 50%        8.500000           -73.981840           40.752678
# 75%       12.500000           -73.967148           40.767360
# max      200.000000            40.783472          401.083332
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger
# count          50000.000000         50000.000000     50000.000000
# mean             -72.504616            39.926251         1.667840
# std               10.407570             6.014737         1.289195
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991152            40.734372         1.000000
# ...

# %%
taxi=taxi.reset_index()

# %%
taxi.head()
# Out:
#    index unique_id  amount       date_time_of_pickup  longitude_of_pickup  \
# 0      0   26:21.0     4.5 2009-06-15 17:26:21+00:00           -73.844311
# 1      1   52:16.0    16.9 2010-01-05 16:52:16+00:00           -74.016048
# 2      2   35:00.0     5.7 2011-08-18 00:35:00+00:00           -73.982738
# 3      3   30:42.0     7.7 2012-04-21 04:30:42+00:00           -73.987130
# 4      4   51:00.0     5.3 2010-03-09 07:51:00+00:00           -73.968095
#
#    latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0           40.721319            -73.841610            40.712278
# 1           40.711303            -73.979268            40.782004
# 2           40.761270            -73.991242            40.750562
# 3           40.733143            -73.991567            40.758092
# 4           40.768008            -73.956655            40.783762
#
#    no_of_passenger
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1

# %%
taxi.duplicated(subset="unique_id").sum()
# Out:
# 46403

# %%
#if we run this code line again it will give error as the unique_id is already dropped
taxi.drop("unique_id", axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 taxi.drop("unique_id", axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
taxi.head()
# Out:
#    index  amount       date_time_of_pickup  longitude_of_pickup  \
# 0      0     4.5 2009-06-15 17:26:21+00:00           -73.844311
# 1      1    16.9 2010-01-05 16:52:16+00:00           -74.016048
# 2      2     5.7 2011-08-18 00:35:00+00:00           -73.982738
# 3      3     7.7 2012-04-21 04:30:42+00:00           -73.987130
# 4      4     5.3 2010-03-09 07:51:00+00:00           -73.968095
#
#    latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0           40.721319            -73.841610            40.712278
# 1           40.711303            -73.979268            40.782004
# 2           40.761270            -73.991242            40.750562
# 3           40.733143            -73.991567            40.758092
# 4           40.768008            -73.956655            40.783762
#
#    no_of_passenger
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1

# %%
taxi[taxi.amount<=0].index
# Out:
# Index([2039, 2486, 10002, 13032, 27891, 28839, 36722, 42337, 47302], dtype='int64')

# %%
taxi.drop(taxi[taxi.amount<=0].index, axis=0, inplace=True)

# %%
taxi.shape
# Out:
# (49991, 8)

# %%
#extract various date time components as seperate variables
taxi = taxi.assign(hour = taxi.date_time_of_pickup.dt.hour, 
                   day = taxi.date_time_of_pickup.dt.day,
                   month = taxi.date_time_of_pickup.dt.month, 
                   year = taxi.date_time_of_pickup.dt.year, 
                   dayofweek = taxi.date_time_of_pickup.dt.dayofweek)

# %%
taxi.drop("date_time_of_pickup", axis=1, inplace=True)

# %%
taxi.head()
# Out:
#    index  amount  longitude_of_pickup  latitude_of_pickup  \
# 0      0     4.5           -73.844311           40.721319
# 1      1    16.9           -74.016048           40.711303
# 2      2     5.7           -73.982738           40.761270
# 3      3     7.7           -73.987130           40.733143
# 4      4     5.3           -73.968095           40.768008
#
#    longitude_of_dropoff  latitude_of_dropoff  no_of_passenger  hour  day  \
# 0            -73.841610            40.712278                1    17   15
# 1            -73.979268            40.782004                1    16    5
# 2            -73.991242            40.750562                2     0   18
# 3            -73.991567            40.758092                1     4   21
# 4            -73.956655            40.783762                1     7    9
#
#    month  year  dayofweek
# 0      6  2009          0
# 1      1  2010          1
# 2      8  2011          3
# 3      4  2012          5
# 4      3  2010          1

# %%
taxi.latitude_of_pickup.value_counts()
# Out:
# latitude_of_pickup
# 0.000000     955
# 41.366138     18
# 40.756007     10
# 40.763975      8
# 40.757500      7
#             ...
# 40.725295      1
# 40.768578      1
# 40.740649      1
# 40.772588      1
# 40.768434      1
# Name: count, Length: 36587, dtype: int64

# %%
taxi.drop(taxi[(taxi.latitude_of_pickup==0) |
               (taxi.longitude_of_pickup==0) |
               (taxi.latitude_of_dropoff==0) |
               (taxi.longitude_of_dropoff==0)].index,inplace=True)

# %%
taxi.shape
# Out:
# (48992, 11)

# %%
taxi.latitude_of_pickup.replace(401.083332, 40.1083332, inplace=True)
# Out:
# C:\Users\Aamir\AppData\Local\Temp\ipykernel_20624\1942930572.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   taxi.latitude_of_pickup.replace(401.083332, 40.1083332, inplace=True)

# %%
taxi.latitude_of_pickup.sort_values(ascending=True)
# Out:
# 8443    -74.006893
# 10091   -74.006210
# 31847   -74.004027
# 41872   -73.995000
# 9548    -73.992947
#            ...
# 28373    41.391042
# 42869    41.523217
# 43305    41.650000
# 35211    42.160275
# 28274    43.098708
# Name: latitude_of_pickup, Length: 48992, dtype: float64

# %%
taxi.describe()
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  48992.000000         48992.000000        48992.000000
# mean      11.362482           -73.927624           40.703940
# std        9.655941             2.308123            2.281165
# min        0.010000           -75.423848          -74.006893
# 25%        6.000000           -73.992297           40.736466
# 50%        8.500000           -73.982115           40.753412
# 75%       12.500000           -73.968355           40.767755
# max      200.000000            40.783472           43.098708
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger  \
# count          48992.000000         48992.000000     48992.000000
# mean             -73.920886            40.703647         1.669354
# std                2.396053             2.289503         1.290292
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991327            40.735862         1.000000
# ...

# %%
#!pip install haversine

# %%
from haversine import haversine, Unit
#df.apply(lambda x: func(x['col1'],x['col2']),axis=1)
#haversine((lat1,long1),(lat2,long2))
taxi['travel_dist_km']=taxi.apply(lambda row: haversine((row["latitude_of_pickup"],row["longitude_of_pickup"]),
                                                        (row["latitude_of_dropoff"],row["longitude_of_dropoff"]),
                                                              unit=Unit.KILOMETERS),axis=1)
taxi['travel_dist_km']=taxi['travel_dist_km'].round(2)

# %%
taxi.head()
# Out:
#    amount  longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 0     4.5           -73.844311           40.721319            -73.841610
# 1    16.9           -74.016048           40.711303            -73.979268
# 2     5.7           -73.982738           40.761270            -73.991242
# 3     7.7           -73.987130           40.733143            -73.991567
# 4     5.3           -73.968095           40.768008            -73.956655
#
#    latitude_of_dropoff  no_of_passenger  hour  day  month  year  dayofweek  \
# 0            40.712278                1    17   15      6  2009          0
# 1            40.782004                1    16    5      1  2010          1
# 2            40.750562                2     0   18      8  2011          3
# 3            40.758092                1     4   21      4  2012          5
# 4            40.783762                1     7    9      3  2010          1
#
#    travel_dist_km
# 0            1.03
# 1            8.45
# ...

# %%
taxi.columns
# Out:
# Index(['amount', 'longitude_of_pickup', 'latitude_of_pickup',
#        'longitude_of_dropoff', 'latitude_of_dropoff', 'no_of_passenger',
#        'hour', 'day', 'month', 'year', 'dayofweek', 'travel_dist_km'],
#       dtype='object')

# %%
taxi.drop(["longitude_of_pickup","latitude_of_pickup","longitude_of_dropoff","latitude_of_dropoff"],axis=1,inplace=True)

# %%
taxi
# Out:
#        amount  no_of_passenger  hour  day  month  year  dayofweek  \
# 0         4.5                1    17   15      6  2009          0
# 1        16.9                1    16    5      1  2010          1
# 2         5.7                2     0   18      8  2011          3
# 3         7.7                1     4   21      4  2012          5
# 4         5.3                1     7    9      3  2010          1
# ...       ...              ...   ...  ...    ...   ...        ...
# 49995    15.0                1    23   12      6  2013          2
# 49996     7.5                1    17   22      6  2015          0
# 49997     6.9                1     4   30      1  2011          6
# 49998     4.5                2     7    6     11  2012          1
# 49999    10.9                1     8   13      1  2010          2
#
#        travel_dist_km
# 0                1.03
# 1                8.45
# 2                1.39
# 3                2.80
# 4                2.00
# ...               ...
# ...

# %%
X=taxi.values[:,1:]
Y=taxi.values[:,0]

#X=dp.drop)"amount").values
#Y=dp["amount"].values

# %%
from sklearn.preprocessing import StandardScaler

scaler= StandardScaler()

scaler.fit(X)
X= scaler.transform(X)

# %%
from sklearn.model_selection import train_test_split

#split the data into test and train
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3,
                                                    random_state=10)

# %%
#predicting using the decisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor

model_DecisionTree=  DecisionTreeRegressor(criterion="squared_error",random_state=10)
model_DecisionTree.fit(X_train, Y_train)
#fit tje model on the data and oredict the values
Y_pred=model_DecisionTree.predict(X_test)
print(Y_pred)
# Out:
# [36.5  5.   8.9 ... 11.5 15.5 11. ]

# %%
model_DecisionTree.score(X_train, Y_train)
# Out:
# 0.9999926735062961

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np
 
r2=r2_score(Y_test,Y_pred)
print("R-squared:",r2)
 
rmse=np.sqrt(mean_squared_error(Y_test,Y_pred))
print("RMSE:",rmse)
 
adjusted_r_squared = 1 - (1-r2)*(len(Y)-1)/(len(Y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# R-squared: 0.41934728538014276
# RMSE: 7.293701662626026
# Adj R-square: 0.4192643078976518

# %%
#predicting using the decision tree regressor
from sklearn.tree import DecisionTreeRegressor

model_DecisionTree=  DecisionTreeRegressor(max_depth=5,min_samples_leaf=5,
                                          random_state=10)
model_DecisionTree.fit(X_train, Y_train)
#fit tje model on the data and oredict the values
Y_pred=model_DecisionTree.predict(X_test)
print(Y_pred)
# Out:
# [26.31727147  5.50436867  9.68327851 ... 10.02815744 18.94743557
#  10.02815744]

# %%
model_DecisionTree.score(X_train, Y_train)
# Out:
# 0.7461592894163125

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np
 
r2=r2_score(Y_test,Y_pred)
print("R-squared:",r2)
 
rmse=np.sqrt(mean_squared_error(Y_test,Y_pred))
print("RMSE:",rmse)
 
adjusted_r_squared = 1 - (1-r2)*(len(Y)-1)/(len(Y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# R-squared: 0.7861636482405271
# RMSE: 4.426194895667306
# Adj R-square: 0.7861330902121441

# %%
print(list(zip(taxi.columns[1:],model_DecisionTree.feature_importances_)))
# Out:
# [('no_of_passenger', 0.0), ('hour', 0.0016419068255963175), ('day', 0.0), ('month', 0.0), ('year', 0.02160810007674775), ('dayofweek', 0.0010219225126868697), ('travel_dist_km', 0.9757280705849691)]

# %%
sample=pd.DataFrame()

sample["Columns"]=taxi.columns[1:]
sample["Imp value"]=model_DecisionTree.feature_importances_

sample.sort_values("Imp value", ascending=False)
# Out:
#            Columns  Imp value
# 6   travel_dist_km   0.975728
# 4             year   0.021608
# 1             hour   0.001642
# 5        dayofweek   0.001022
# 0  no_of_passenger   0.000000
# 2              day   0.000000
# 3            month   0.000000

# %%
from sklearn import tree
with open("model_DecisionTree.txt", "w") as f:
    f = tree.export_graphviz(model_DecisionTree, feature_names = taxi.columns[1:],
                             out_file=f)

#generate the file and upload the code in webgraphivz.com to plot the decision tree

# %%
#predicting using the random forest regressor
from sklearn.ensemble import RandomForestRegressor

model_DecisionTree=  RandomForestRegressor(n_estimators=100,random_state=10)
model_DecisionTree.fit(X_train, Y_train)
#fit tje model on the data and oredict the values
Y_pred=model_DecisionTree.predict(X_test)
print(Y_pred)
# Out:
# [28.6571  5.61    8.275  ... 10.465  19.145   8.615 ]

# %%
model_DecisionTree.score(X_train, Y_train)
# Out:
# 0.7523209862686894

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np
 
r2=r2_score(Y_test,Y_pred)
print("R-squared:",r2)
 
rmse=np.sqrt(mean_squared_error(Y_test,Y_pred))
print("RMSE:",rmse)
 
adjusted_r_squared = 1 - (1-r2)*(len(Y)-1)/(len(Y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# R-squared: 0.7688683364173281
# RMSE: 4.601712558667241
# Adj R-square: 0.7688353068230712

# %%
#prdicting using the randomforestregressor(best model from all of others)
from sklearn.ensemble import RandomForestRegressor

model_DecisionTree=  RandomForestRegressor(n_estimators=100,random_state=10,
                                          max_depth=5,min_samples_leaf=5)
model_DecisionTree.fit(X_train, Y_train)
#fit the model on the data and predict the values
Y_pred=model_DecisionTree.predict(X_test)
print(Y_pred)
# Out:
# [26.58723949  5.48362388  9.45751295 ... 10.79499642 19.35004592
#   9.80453887]

# %%
model_DecisionTree.score(X_train, Y_train)
# Out:
# 0.7523209862686894

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np
 
r2=r2_score(Y_test,Y_pred)
print("R-squared:",r2)
 
rmse=np.sqrt(mean_squared_error(Y_test,Y_pred))
print("RMSE:",rmse)
 
adjusted_r_squared = 1 - (1-r2)*(len(Y)-1)/(len(Y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# R-squared: 0.7924955610078093
# RMSE: 4.36017038391129
# Adj R-square: 0.7924659078338556

# %%
sample=pd.DataFrame()

sample["Columns"]=taxi.columns[1:]
sample["Imp value"]=model_DecisionTree.feature_importances_

sample.sort_values("Imp value", ascending=False)
# Out:
#            Columns  Imp value
# 6   travel_dist_km   0.972719
# 4             year   0.021811
# 1             hour   0.003477
# 3            month   0.000884
# 5        dayofweek   0.000592
# 2              day   0.000310
# 0  no_of_passenger   0.000207

# %%
#prdicting using the randomforestregressor
from sklearn.ensemble import ExtraTreesRegressor

model_DecisionTree= ExtraTreesRegressor(n_estimators=100,random_state=10, bootstrap=True,
                                       max_depth=5,min_samples_leaf=5)
model_DecisionTree.fit(X_train, Y_train)
#fit the model on the data and predict the values
Y_pred=model_DecisionTree.predict(X_test)
print(Y_pred)
# Out:
# [11.25343918 10.2137769   9.22684473 ... 11.57628794 16.57729021
#  10.89544267]

# %%
model_DecisionTree.score(X_train, Y_train)
# Out:
# 0.39853627129784774

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np
 
r2=r2_score(Y_test,Y_pred)
print("R-squared:",r2)
 
rmse=np.sqrt(mean_squared_error(Y_test,Y_pred))
print("RMSE:",rmse)
 
adjusted_r_squared = 1 - (1-r2)*(len(Y)-1)/(len(Y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# R-squared: 0.4291842698232019
# RMSE: 7.231655533375233
# Adj R-square: 0.42910269808322077
